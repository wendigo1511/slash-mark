# %%
import random
import time

def intro():
    print("Welcome to the number guessing game!")
    print("I'm thinking of a number between 1 and 200.")
    print("You have 6 attempts to guess the number.")
    print("Good luck!")

def get_guess():
    while True:
        try:
            guess = int(input("Enter your guess: "))
            if guess < 1 or guess > 200:
                print("Sorry, that number isn't in the range!")
                print("Please enter a number between 1 and 200.")
            else:
                return guess
        except ValueError:
            print("I don't think that's a number. Please try again.")

def play_game():
    intro()
    number = random.randint(1, 200)
    guesses_taken = 0
    guess = None

    while guesses_taken < 6:
        guess = get_guess()
        guesses_taken += 1

        if guess < number:
            print("The guess of the number that you have entered is too low.")
        elif guess > number:
            print("The guess of the number that you have entered is too high.")
        else:
            guesses_taken = str(guesses_taken)
            print(f'Good job, {name}! You guessed my number in {guesses_taken} guesses!')
            break

    if guess != number:
        print(f'Nope. The number I was thinking of was {number}.')

def play_again():
    while True:
        play_again = input("Do you want to play again? (yes/no): ")
        if play_again.lower() == "yes" or play_again.lower() == "y":
            return True
        elif play_again.lower() == "no" or play_again.lower() == "n":
            return False
        else:
            print("Sorry, I didn't understand that. Please enter 'yes' or 'no'.")

if __name__ == "__main__":
    name = input("May I ask you for your name? ")
    print(f"{name}, let's play the number guessing game!")

    while True:
        play_game()
        if not play_again():
            break

    print("Thanks for playing!")
# Out:
# May I ask you for your name? syd
# syd, let's play the number guessing game!
# Welcome to the number guessing game!
# I'm thinking of a number between 1 and 200.
# You have 6 attempts to guess the number.
# Good luck!
# Enter your guess: 189
# The guess of the number that you have entered is too high.
# Enter your guess: 50
# The guess of the number that you have entered is too high.
# Enter your guess: 201
# Sorry, that number isn't in the range!
# Please enter a number between 1 and 200.
# Enter your guess: asdfa
# I don't think that's a number. Please try again.
# Enter your guess: 100
# The guess of the number that you have entered is too high.
# Enter your guess: 3
# The guess of the number that you have entered is too low.
# Enter your guess: 30
# The guess of the number that you have entered is too low.
# Enter your guess: 40
# The guess of the number that you have entered is too low.
# Nope. The number I was thinking of was 45.
# Do you want to play again? (yes/no): no
# ...
